# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\kalyani\desktop\bhargavi\venv\lib\site-packages (2.34.2)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\kalyani\desktop\bhargavi\venv\lib\site-packages (from requests) (2026.7.22)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kalyani\desktop\bhargavi\venv\lib\site-packages (from requests) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\kalyani\desktop\bhargavi\venv\lib\site-packages (from requests) (2.7.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kalyani\desktop\bhargavi\venv\lib\site-packages (from requests) (3.18)
# [notice] A new release of pip is available: 23.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests

API_KEY = "70abd55a-2c29-428a-b5a6-de2b8cc30f63"

url = "https://api.cricapi.com/v1/currentMatches"

params = {
    "apikey": API_KEY,
    "offset": 0
}

response = requests.get(url, params=params)

print("Status Code:", response.status_code)
# Out:
# Status Code: 200

# %%
data = response.json()

print(data)
# Out:
# {'apikey': '70abd55a-2c29-428a-b5a6-de2b8cc30f63', 'data': [{'id': 'ca1a54c7-6c4d-4a33-a11d-5d025494ce8e', 'name': 'Papua New Guinea Women vs Thailand Women, 3rd ODI, Thailand Women tour of Papua New Guinea, 2026', 'status': 'Thailand Women won by 5 wkts', 'venue': 'Amini Park, Port Moresby', 'date': '2026-08-17', 'dateTimeGMT': '2026-08-17T23:30:00', 'teams': ['Papua New Guinea Women', 'Thailand Women'], 'teamInfo': [{'name': 'Papua New Guinea Women', 'shortname': 'PN -W', 'img': 'https://g.cricapi.com/iapi/2425-637991983542500362.webp?w=48'}, {'name': 'Thailand Women', 'shortname': 'THW', 'img': 'https://g.cricapi.com/iapi/2351-637985730472466346.webp?w=48'}], 'score': [{'r': 122, 'w': 10, 'o': 47, 'inning': 'papua new guinea women Inning 1'}, {'r': 126, 'w': 5, 'o': 27, 'inning': 'Papua New Guinea Women,Thailand Women Inning 1'}], 'series_id': '639d4a51-6405-402a-9281-17e7922e5a25', 'fantasyEnabled': False, 'bbbEnabled': False, 'hasSquad': False, 'matchStarted': True, 'matchEnded': True}, {'id': '1fa3bd8a-4bac-4ebb-b022-aba8281467e3', 'name': 'Tanzania Women vs Uganda Women, 12th Match, Womens T20I Quadrangular Series in Namibia 2026', 'matchType': 't20', 'status': 'Tanzania Women awarded the match (opposition refused to play)', 'venue': 'Namibia Cricket Ground, Windhoek', 'date': '2026-07-28', 'dateTimeGMT': '2026-07-28T12:00:00', 'teams': ['Tanzania Women', 'Uganda Women'], 'teamInfo': [{'name': 'Tanzania Women', 'shortname': 'TAN-W', 'img': 'https://g.cricapi.com/iapi/3614-638101761273860958.webp?w=48'}, {'name': 'Uganda Women', 'shortname': 'UGAW', 'img': 'https://g.cricapi.com/iapi/1135-637877086844153505.webp?w=48'}], 'score': [{'r': 116, 'w': 2, 'o': 16.4, 'inning': 'Uganda Women Inning 1'}], 'series_id': '3014a459-6e69-4f64-86eb-2f30a2cdbd0b', 'fantasyEnabled': True, 'bbbEnabled': False, 'hasSquad': False, 'matchStarted': True, 'matchEnded': False}, {'id': 'fee080ab-e8fe-4579-9e81-40d75f31ebbb', 'name': 'Saint Lucia Kings vs Barbados Tridents, 9th Match, Caribbean Premier League 2026', 'matchType': 't20', 'status': 'Barbados Tridents won by 9 runs - 18 overs game due to rain', 'venue': 'Daren Sammy National Cricket Stadium, Gros Islet, St Lucia', 'date': '2026-08-16', 'dateTimeGMT': '2026-08-16T23:00:00', 'teams': ['Saint Lucia Kings', 'Barbados Tridents'], 'teamInfo': [{'name': 'Barbados Tridents', 'img': 'https://h.cricapi.com/img/icon512.png'}, {'name': 'Saint Lucia Kings', 'shortname': 'SLK', 'img': 'https://g.cricapi.com/iapi/266-637937643184202597.webp?w=48'}], 'score': [{'r': 177, 'w': 5, 'o': 18, 'inning': 'Barbados Tridents Inning 1'}, {'r': 168, 'w': 7, 'o': 18, 'inning': 'Saint Lucia Kings Inning 1'}], 'series_id': '929c36f6-9ed6-4cec-a2ad-910a2ee4f701', 'fantasyEnabled': False, 'bbbEnabled': False, 'hasSquad': False, 'matchStarted': True, 'matchEnded': True}, {'id': '2c792f39-5c37-43e7-917c-44e5f62b1f43', 'name': 'Jamaica Kingsmen vs Trinbago Knight Riders, 8th Match, Caribbean Premier League 2026', 'matchType': 't20', 'status': 'Jamaica Kingsmen won by 5 wkts', 'venue': 'Sabina Park, Kingston, Jamaica', 'date': '2026-08-15', 'dateTimeGMT': '2026-08-15T00:00:00', 'teams': ['Jamaica Kingsmen', 'Trinbago Knight Riders'], 'teamInfo': [{'name': 'Jamaica Kingsmen', 'img': 'https://h.cricapi.com/img/icon512.png'}, {'name': 'Trinbago Knight Riders', 'shortname': 'TKR', 'img': 'https://g.cricapi.com/iapi/293-637932465560269082.png?w=48'}], 'score': [{'r': 182, 'w': 6, 'o': 20, 'inning': 'Trinbago Knight Riders Inning 1'}, {'r': 183, 'w': 5, 'o': 18.4, 'inning': 'Jamaica Kingsmen Inning 1'}], 'series_id': '929c36f6-9ed6-4cec-a2ad-910a2ee4f701', 'fantasyEnabled': False, 'bbbEnabled': False, 'hasSquad': False, 'matchStarted': True, 'matchEnded': True}, {'id': '03481413-2204-474a-8fba-251011e4f437', 'name': 'Saint Lucia Kings vs Antigua and Barbuda Falcons, 7th Match, Caribbean Premier League 2026', 'matchType': 't20', 'status': 'Saint Lucia Kings won by 3 wkts (2nd innings reduced to 8 overs due to rain, DLS target ...

# %%
print(data.keys())
# Out:
# dict_keys(['apikey', 'data', 'status', 'info'])

# %%
data["data"]
# Out:
# [{'id': 'ca1a54c7-6c4d-4a33-a11d-5d025494ce8e',
#   'name': 'Papua New Guinea Women vs Thailand Women, 3rd ODI, Thailand Women tour of Papua New Guinea, 2026',
#   'status': 'Thailand Women won by 5 wkts',
#   'venue': 'Amini Park, Port Moresby',
#   'date': '2026-08-17',
#   'dateTimeGMT': '2026-08-17T23:30:00',
#   'teams': ['Papua New Guinea Women', 'Thailand Women'],
#   'teamInfo': [{'name': 'Papua New Guinea Women',
#     'shortname': 'PN -W',
#     'img': 'https://g.cricapi.com/iapi/2425-637991983542500362.webp?w=48'},
#    {'name': 'Thailand Women',
#     'shortname': 'THW',
#     'img': 'https://g.cricapi.com/iapi/2351-637985730472466346.webp?w=48'}],
#   'score': [{'r': 122,
#     'w': 10,
#     'o': 47,
#     'inning': 'papua new guinea women Inning 1'},
#    {'r': 126,
#     'w': 5,
#     'o': 27,
#     'inning': 'Papua New Guinea Women,Thailand Women Inning 1'}],
#   'series_id': '639d4a51-6405-402a-9281-17e7922e5a25',
#   'fantasyEnabled': False,
#   'bbbEnabled': False,
#   'hasSquad': False,
#   'matchStarted': True,
#   'matchEnded': True},
#  {'id': '1fa3bd8a-4bac-4ebb-b022-aba8281467e3',
#   'name': 'Tanzania Women vs Uganda Women, 12th Match, Womens T20I Quadrangular Series in Namibia 2026',
#   'matchType': 't20',
#   'status': 'Tanzania Women awarded the match (opposition refused to play)',
#   'venue': 'Namibia Cricket Ground, Windhoek',
#   'date': '2026-07-28',
#   'dateTimeGMT': '2026-07-28T12:00:00',
#   'teams': ['Tanzania Women', 'Uganda Women'],
#   'teamInfo': [{'name': 'Tanzania Women',
#     'shortname': 'TAN-W',
#     'img': 'https://g.cricapi.com/iapi/3614-638101761273860958.webp?w=48'},
#    {'name': 'Uganda Women',
#     'shortname': 'UGAW',
#     'img': 'https://g.cricapi.com/iapi/1135-637877086844153505.webp?w=48'}],
#   'score': [{'r': 116, 'w': 2, 'o': 16.4, 'inning': 'Uganda Women Inning 1'}],
#   'series_id': '3014a459-6e69-4f64-86eb-2f30a2cdbd0b',
#   'fantasyEnabled': True,
#   'bbbEnabled': False,
#   'hasSquad': False,
#   'matchStarted': True,
#   'matchEnded': False},
#  {'id': 'fee080ab-e8fe-4579-9e81-40d75f31ebbb',
#   'name': 'Saint Lucia Kings vs Barbados Tridents, 9th Match, Caribbean Premier League 2026',
#   'matchType': 't20',
#   'status': 'Barbados Tridents won by 9 runs - 18 overs game due to rain',
#   'venue': 'Daren Sammy National Cricket Stadium, Gros Islet, St Lucia',
#   'date': '2026-08-16',
#   'dateTimeGMT': '2026-08-16T23:00:00',
#   'teams': ['Saint Lucia Kings', 'Barbados Tridents'],
#   'teamInfo': [{'name': 'Barbados Tridents',
#     'img': 'https://h.cricapi.com/img/icon512.png'},
#    {'name': 'Saint Lucia Kings',
#     'shortname': 'SLK',
#     'img': 'https://g.cricapi.com/iapi/266-637937643184202597.webp?w=48'}],
#   'score': [{'r': 177,
#     'w': 5,
#     'o': 18,
#     'inning': 'Barbados Tridents Inning 1'},
#    {'r': 168, 'w': 7, 'o': 18, 'inning': 'Saint Lucia Kings Inning 1'}],
#   'series_id': '929c36f6-9ed6-4cec-a2ad-910a2ee4f701',
#   'fantasyEnabled': False,
#   'bbbEnabled': False,
#   'hasSquad': False,
#   'matchStarted': True,
#   'matchEnded': True},
#  {'id': '2c792f39-5c37-43e7-917c-44e5f62b1f43',
#   'name': 'Jamaica Kingsmen vs Trinbago Knight Riders, 8th Match, Caribbean Premier League 2026',
#   'matchType': 't20',
#   'status': 'Jamaica Kingsmen won by 5 wkts',
#   'venue': 'Sabina Park, Kingston, Jamaica',
#   'date': '2026-08-15',
#   'dateTimeGMT': '2026-08-15T00:00:00',
#   'teams': ['Jamaica Kingsmen', 'Trinbago Knight Riders'],
#   'teamInfo': [{'name': 'Jamaica Kingsmen',
#     'img': 'https://h.cricapi.com/img/icon512.png'},
#    {'name': 'Trinbago Knight Riders',
#     'shortname': 'TKR',
#     'img': 'https://g.cricapi.com/iapi/293-637932465560269082.png?w=48'}],
#   'score': [{'r': 182,
#     'w': 6,
#     'o': 20,
#     'inning': 'Trinbago Knight Riders Inning 1'},
#    {'r': 183, 'w': 5, 'o': 18.4, 'inning': 'Jamaica Kingsmen Inning 1'}],
#   'series_id': '929c36f6-9ed6-4cec-a2ad-910a2ee4f701',
#   'fantasyEnabled': False,
#   'bbbEnabled': False,
#   'hasSquad': False,
#   'matchStarted': True,
#   'matchEnded': True},
#  {'id': '03481413-2204-474a-8fba-251011e4f437',
#   'name': 'Saint Lucia Kings vs Antigua and Barbuda Falcons, 7th Match, Caribbean Premier League 2026',
#   'matchType': 't20',
#   'status': 'Saint Lucia Kings won by 3 wkts (2nd innings reduced to 8 overs due to rain, DLS target 52)',
#   'venue': 'Daren Sammy National Cricket Stadium, Gros Islet, St Lucia',
#   'date': '2026-08-14',
#   'dateTimeGMT': '2026-08-14T23:00:00',
#   'teams': ['Saint Lucia Kings', 'Antigua and Barbuda Falcons'],
#   'teamInfo': [{'name': 'Antigua and Barbuda Falcons',
#     'shortname': 'ABF',
#     'img': 'https://h.cricapi.com/img/icon512.png'},
#    {'name': 'Saint Lucia Kings',
#     'shortname': 'SLK',
#     'img': 'https://g.cricapi.com/iapi/266-637937643184202597.webp?w=48'}],
#   'score': [{'r': 98,
#     'w': 9,
#     'o': 19,
#     'inning': 'Antigua and Barbuda Falcons Inning 1'},
#    {'r': 54, 'w': 7, 'o': 7.4, 'inning': 'Saint Lucia Kings Inning 1'}],
#   'series_id': '929c36f6-9ed6-4cec-a2ad-910a2ee4f701',
#   'fantasyEnabled': False,
#   'bbbEnabled': False,
#   'hasSquad': False,
#   'matchStarted': True,
#   'matchEnded': True},
#  {'id': 'e9d200fb-3c43-4852-9c93-9160517d7b36',
#   'name': 'Chepauk Super Gillies vs Vida Kovai Kings, 21st Match, Tamil Nadu Premier League 2026',
#   'matchType': 't20',
#   'status': 'Vida Kovai Kings need 67 runs in 59 balls',
#   'venue': 'MA Chidambaram Stadium, Chennai',
#   'date': '2026-08-18',
#   'dateTimeGMT': '2026-08-18T14:00:00',
#   'teams': ['Chepauk Super Gillies', 'Vida Kovai Kings'],
#   'teamInfo': [{'name': 'Chepauk Super Gillies',
#     'shortname': 'CSG',
#     'img': 'https://g.cricapi.com/iapi/136-637957472174708637.webp?w=48'},
#    {'name': 'Vida Kovai Kings',
#     'img': 'https://h.cricapi.com/img/icon512.png'}],
#   'score': [{'r': 167,
#     'w': 10,
#     'o': 19.3,
#     'inning': 'Chepauk Super Gillies Inning 1'},
#    {'r': 101, 'w': 1, 'o': 10.1, 'inning': 'Vida Kovai Kings Inning 1'}],
#   'series_id': '6c3c5876-5cfc-4490-9c8e-8ba90aec4323',
#   'fantasyEnabled': False,
#   'bbbEnabled': False,
#   'hasSquad': False,
#   'matchStarted': True,
#   'matchEnded': False},
#  {'id': '793fd4ac-a2ee-4ca7-90ec-63743393d32e',
#   'name': 'Vida Kovai Kings vs Trichy Grand Cholas, 20th Match, Tamil Nadu Premier League 2026',
#   'matchType': 't20',
#   'status': 'Vida Kovai Kings won by 116 runs',
#   'venue': 'NPR College Ground, Dindigul',
#   'date': '2026-08-15',
#   'dateTimeGMT': '2026-08-15T14:00:00',
#   'teams': ['Vida Kovai Kings', 'Trichy Grand Cholas'],
#   'teamInfo': [{'name': 'Trichy Grand Cholas',
#     'shortname': 'TGC',
#     'img': 'https://h.cricapi.com/img/icon512.png'},
#    {'name': 'Vida Kovai Kings',
#     'img': 'https://h.cricapi.com/img/icon512.png'}],
#   'score': [{'r': 201, 'w': 6, 'o': 20, 'inning': 'Vida Kovai Kings Inning 1'},
#    {'r': 85, 'w': 10, 'o': 16.1, 'inning': 'Trichy Grand Cholas Inning 1'}],
#   'series_id': '6c3c5876-5cfc-4490-9c8e-8ba90aec4323',
#   'fantasyEnabled': False,
#   'bbbEnabled': False,
#   'hasSquad': False,
#   'matchStarted': True,
#   'matchEnded': True},
#  {'id': 'af3a2cab-6dff-491c-b126-3c58b1084b9f',
#   'name': 'Madurai Panthers vs Chepauk Super Gillies, 19th Match, Tamil Nadu Premier League 2026',
#   'matchType': 't20',
#   'status': 'Chepauk Super Gillies won by 39 runs',
#   'venue': 'NPR College Ground, Dindigul',
#   'date': '2026-08-14',
#   'dateTimeGMT': '2026-08-14T14:00:00',
#   'teams': ['Madurai Panthers', 'Chepauk Super Gillies'],
#   'teamInfo': [{'name': 'Chepauk Super Gillies',
#     'shortname': 'CSG',
#     'img': 'https://g.cricapi.com/iapi/136-637957472174708637.webp?w=48'},
#    {'name': 'Madurai Panthers',
#     'shortname': 'MP',
#     'img': 'https://g.cricapi.com/iapi/217-637940203723122310.webp?w=48'}],
#   'score': [{'r': 240, 'w': 2, 'o': 20, 'inning': 'Madurai Panthers Inning 1'},
#    {'r': 201, 'w': 8, 'o': 20, 'inning': 'Chepauk Super Gillies Inning 1'}],
#   'series_id': '6c3c5876-5cfc-4490-9c8e-8ba90aec4323',
#   'fantasyEnabled': False,
#   'bbbEnabled': False,
#   'hasSquad': False,
#   'matchStarted': True,
#   'matchEnded': True},
#  {'id': '32b78568-9a24-4ed9-9a4e-43b9b56ea4ae',
#   'name': 'SKM Salem Spartans vs Dindigul Dragons, 18th Match, Tamil Nadu Premier League 2026',
#   'matchType': 't20',
#   'status': 'Dindigul Dragons won by 82 runs - 15 overs game due to rain',
#   'venue': 'NPR College Ground, Dindigul',
#   'date': '2026-08-14',
#   'dateTimeGMT': '2026-08-14T10:00:00',
#   'teams': ['SKM Salem Spartans', 'Dindigul Dragons'],
#   'teamInfo': [{'name': 'Dindigul Dragons',
#     'shortname': 'DD',
#     'img': 'https://g.cricapi.com/iapi/153-637951184351143751.webp?w=48'},
#    {'name': 'SKM Salem Spartans',
#     'img': 'https://h.cricapi.com/img/icon512.png'}],
#   'score': [{'r': 239, 'w': 6, 'o': 15, 'inning': 'Dindigul Dragons Inning 1'},
#    {'r': 157, 'w': 8, 'o': 15, 'inning': 'SKM Salem Spartans Inning 1'}],
#   'series_id': '6c3c5876-5cfc-4490-9c8e-8ba90aec4323',
#   'fantasyEnabled': False,
#   'bbbEnabled': False,
#   'hasSquad': False,
#   'matchStarted': True,
#   'matchEnded': True},
#  {'id': '395791ba-6c70-4887-a6f2-5f8a4eaf33e0',
#   'name': 'Ireland vs Afghanistan, 5th ODI, Afghanistan tour of Ireland, 2026',
#   'matchType': 'odi',
#   'status': 'Afghanistan won by 6 wkts',
#   'venue': 'Civil Service Cricket Club, Belfast',
#   'date': '2026-08-14',
#   'dateTimeGMT': '2026-08-14T09:45:00',
#   'teams': ['Ireland', 'Afghanistan'],
#   'teamInfo': [{'name': 'Afghanistan',
#     'shortname': 'AFG',
#     'img': 'https://g.cricapi.com/iapi/1-637877075587179422.webp?w=48'},
#    {'name': 'Ireland',
#     'shortname': 'IRE',
#     'img': 'https://g.cricapi.com/iapi/33-637926315578500224.png?w=48'}],
#   'score': [{'r': 298, 'w': 7, 'o': 50, 'inning': 'Ireland Inning 1'},
#    {'r': 302, 'w': 4, 'o': 48.5, 'inning': 'Afghanistan Inning 1'}],
#   'series_id': '2a1567e1-5bdd-4bdb-b60b-1979c5193533',
#   'fantasyEnabled': False,
#   'bbbEnabled': False,
#   'hasSquad': False,
#   'matchStarted': True,
#   'matchEnded': True},
#  {'id': 'a031df55-6d10-4dfd-b45c-ba4fc9edeaa0',
#   'name': 'Trent Rockets vs Manchester Super Giants, Final, The Hundred Mens Competition 2026',
#   'matchType': 't20',
#   'status': 'Manchester Super Giants won by 5 wkts',
#   'venue': "Lord's, London",
#   'date': '2026-08-16',
#   'dateTimeGMT': '2026-08-16T17:00:00',
#   'teams': ['Trent Rockets', 'Manchester Super Giants'],
#   'teamInfo': [{'name': 'Manchester Super Giants',
#     'shortname': 'MSG',
#     'img': 'https://h.cricapi.com/img/icon512.png'},
#    {'name': 'Trent Rockets',
#     'shortname': 'TRE',
#     'img': 'https://g.cricapi.com/iapi/292-637885742365093855.webp?w=48'}],
#   'score': [{'r': 158, 'w': 8, 'o': 100, 'inning': 'Trent Rockets Inning 1'},
#    {'r': 162, 'w': 5, 'o': 98, 'inning': 'Manchester Super Giants Inning 1'}],
#   'series_id': 'ac5127e7-663b-4666-83ca-38f5d6935228',
#   'fantasyEnabled': False,
#   'bbbEnabled': False,
#   'hasSquad': False,
#   'matchStarted': True,
#   'matchEnded': True},
#  {'id': 'ffeeb4bf-b954-45e4-a016-0a392cc2d2fc',
#   'name': 'Manchester Super Giants vs Sunrisers Leeds, Eliminator, The Hundred Mens Competition 2026',
#   'matchType': 't20',
#   'status': 'Manchester Super Giants won by 20 runs',
#   'venue': 'Kennington Oval, London',
#   'date': '2026-08-14',
#   'dateTimeGMT': '2026-08-14T17:00:00',
#   'teams': ['Manchester Super Giants', 'Sunrisers Leeds'],
#   'teamInfo': [{'name': 'Manchester Super Giants',
#     'shortname': 'MSG',
#     'img': 'https://h.cricapi.com/img/icon512.png'},
#    {'name': 'Sunrisers Leeds',
#     'shortname': 'SL',
#     'img': 'https://h.cricapi.com/img/icon512.png'}],
#   'score': [{'r': 186,
#     'w': 4,
#     'o': 100,
#     'inning': 'Manchester Super Giants Inning 1'},
#    {'r': 166, 'w': 7, 'o': 100, 'inning': 'Sunrisers Leeds Inning 1'}],
#   'series_id': 'ac5127e7-663b-4666-83ca-38f5d6935228',
#   'fantasyEnabled': False,
#   'bbbEnabled': False,
#   'hasSquad': False,
#   'matchStarted': True,
#   'matchEnded': True},
#  {'id': '5a209a6b-c8ed-4931-b392-57d106889dcc',
#   'name': 'Trent Rockets Women vs Sunrisers Leeds Women, Final, The Hundred Womens Competition 2026',
#   'matchType': 't20',
#   'status': 'Trent Rockets Women won by 8 wkts',
#   'venue': "Lord's, London",
#   'date': '2026-08-16',
#   'dateTimeGMT': '2026-08-16T13:15:00',
#   'teams': ['Trent Rockets Women', 'Sunrisers Leeds Women'],
#   'teamInfo': [{'name': 'Sunrisers Leeds Women',
#     'shortname': 'SLW',
#     'img': 'https://h.cricapi.com/img/icon512.png'},
#    {'name': 'Trent Rockets Women',
#     'shortname': 'TRW',
#     'img': 'https://g.cricapi.com/iapi/2034-637967614126146514.webp?w=48'}],
#   'score': [{'r': 91,
#     'w': 10,
#     'o': 91,
#     'inning': 'Sunrisers Leeds Women Inning 1'},
#    {'r': 92, 'w': 2, 'o': 54, 'inning': 'Trent Rockets Women Inning 1'}],
#   'series_id': '99aea2e0-513f-4d4c-b83c-336e456723ae',
#   'fantasyEnabled': False,
#   'bbbEnabled': False,
#   'hasSquad': False,
#   'matchStarted': True,
#   'matchEnded': True},
#  {'id': '24b93d6c-6c73-42e6-8137-686fd1529ed5',
#   'name': 'Sunrisers Leeds Women vs Southern Brave Women, Eliminator, The Hundred Womens Competition 2026',
#   'matchType': 't20',
#   'status': 'Sunrisers Leeds Women won by 5 wkts',
#   'venue': 'Kennington Oval, London',
#   'date': '2026-08-14',
#   'dateTimeGMT': '2026-08-14T13:15:00',
#   'teams': ['Sunrisers Leeds Women', 'Southern Brave Women'],
#   'teamInfo': [{'name': 'Southern Brave Women',
#     'shortname': 'SBW',
#     'img': 'https://g.cricapi.com/iapi/2015-637967614770065340.webp?w=48'},
#    {'name': 'Sunrisers Leeds Women',
#     'shortname': 'SLW',
#     'img': 'https://h.cricapi.com/img/icon512.png'}],
#   'score': [{'r': 114,
#     'w': 7,
#     'o': 100,
#     'inning': 'Southern Brave Women Inning 1'},
#    {'r': 116, 'w': 5, 'o': 89, 'inning': 'Sunrisers Leeds Women Inning 1'}],
#   'series_id': '99aea2e0-513f-4d4c-b83c-336e456723ae',
#   'fantasyEnabled': False,
#   'bbbEnabled': False,
#   'hasSquad': False,
#   'matchStarted': True,
#   'matchEnded': True},
#  {'id': '67b24f5c-ca0b-43ae-8ef2-b199a740bebe',
#   'name': 'Middlesex vs Durham, Semi Final 2, England Domestic One-Day Cup 2026',
#   'matchType': 'odi',
#   'status': 'Middlesex won by 2 wkts',
#   'venue': 'Brunton Memorial Ground, Radlett',
#   'date': '2026-08-16',
#   'dateTimeGMT': '2026-08-16T10:00:00',
#   'teams': ['Middlesex', 'Durham'],
#   'teamInfo': [{'name': 'Durham',
#     'shortname': 'DURH',
#     'img': 'https://g.cricapi.com/iapi/1118-637889090599643548.webp?w=48'},
#    {'name': 'Middlesex',
#     'shortname': 'MDX',
#     'img': 'https://g.cricapi.com/iapi/1127-637889091340507643.webp?w=48'}],
#   'score': [{'r': 254, 'w': 7, 'o': 50, 'inning': 'durham Inning 1'},
#    {'r': 255, 'w': 8, 'o': 48.4, 'inning': 'Middlesex,Durham Inning 1'}],
#   'series_id': '2734957c-528c-4a90-bf0d-17b4c88be4dc',
#   'fantasyEnabled': False,
#   'bbbEnabled': False,
#   'hasSquad': False,
#   'matchStarted': True,
#   'matchEnded': True},
#  {'id': '5ea5f86b-8314-473f-a3cc-3d0decf37012',
#   'name': 'Leicestershire vs Nottinghamshire, Semi Final 1, England Domestic One-Day Cup 2026',
#   'matchType': 'odi',
#   'status': 'Leicestershire won by 23 runs',
#   'venue': 'Grace Road, Leicester',
#   'date': '2026-08-16',
#   'dateTimeGMT': '2026-08-16T10:00:00',
#   'teams': ['Leicestershire', 'Nottinghamshire'],
#   'teamInfo': [{'name': 'Leicestershire',
#     'shortname': 'LECS',
#     'img': 'https://g.cricapi.com/iapi/1126-637889090878436462.webp?w=48'},
#    {'name': 'Nottinghamshire',
#     'shortname': 'NOT',
#     'img': 'https://g.cricapi.com/iapi/1130-637889092060873937.webp?w=48'}],
#   'score': [{'r': 303, 'w': 7, 'o': 50, 'inning': 'nottinghamshire Inning 1'},
#    {'r': 280,
#     'w': 10,
#     'o': 49,
#     'inning': 'Leicestershire,Nottinghamshire Inning 1'}],
#   'series_id': '2734957c-528c-4a90-bf0d-17b4c88be4dc',
#   'fantasyEnabled': False,
#   'bbbEnabled': False,
#   'hasSquad': False,
#   'matchStarted': True,
#   'matchEnded': True},
#  {'id': '63a5a1ab-4a4c-4176-8218-dcfa524e695c',
#   'name': 'Yorkshire vs Nottinghamshire, Quarter Final 2, England Domestic One-Day Cup 2026',
#   'matchType': 'odi',
#   'status': 'Nottinghamshire won by 3 wkts',
#   'venue': 'Clifton Park Ground, York',
#   'date': '2026-08-14',
#   'dateTimeGMT': '2026-08-14T10:00:00',
#   'teams': ['Yorkshire', 'Nottinghamshire'],
#   'teamInfo': [{'name': 'Nottinghamshire',
#     'shortname': 'NOT',
#     'img': 'https://g.cricapi.com/iapi/1130-637889092060873937.webp?w=48'},
#    {'name': 'Yorkshire',
#     'shortname': 'YRK',
#     'img': 'https://g.cricapi.com/iapi/1139-637885552795894277.webp?w=48'}],
#   'score': [{'r': 273, 'w': 9, 'o': 50, 'inning': 'Yorkshire Inning 1'},
#    {'r': 277, 'w': 7, 'o': 48.4, 'inning': 'Nottinghamshire Inning 1'}],
#   'series_id': '2734957c-528c-4a90-bf0d-17b4c88be4dc',
#   'fantasyEnabled': False,
#   'bbbEnabled': False,
#   'hasSquad': False,
#   'matchStarted': True,
#   'matchEnded': True},
#  {'id': 'f2c023fb-8830-4213-9afb-9747138d3d66',
#   'name': 'Lancashire vs Durham, Quarter Final 1, England Domestic One-Day Cup 2026',
#   'matchType': 'odi',
#   'status': 'Durham won by 162 runs',
#   'venue': 'Emirates Old Trafford, Manchester',
#   'date': '2026-08-14',
#   'dateTimeGMT': '2026-08-14T10:00:00',
#   'teams': ['Lancashire', 'Durham'],
#   'teamInfo': [{'name': 'Durham',
#     'shortname': 'DURH',
#     'img': 'https://g.cricapi.com/iapi/1118-637889090599643548.webp?w=48'},
#    {'name': 'Lancashire',
#     'shortname': 'LNCS',
#     'img': 'https://g.cricapi.com/iapi/1125-637885551497331567.webp?w=48'}],
#   'score': [{'r': 349, 'w': 8, 'o': 50, 'inning': 'durham Inning 1'},
#    {'r': 187, 'w': 10, 'o': 36.1, 'inning': 'Lancashire,Durham Inning 1'}],
#   'series_id': '2734957c-528c-4a90-bf0d-17b4c88be4dc',
#   'fantasyEnabled': False,
#   'bbbEnabled': False,
#   'hasSquad': False,
#   'matchStarted': True,
#   'matchEnded': True}]

# %%
print(data.keys())
# Out:
# dict_keys(['apikey', 'data', 'status', 'info'])

# %%
print(len(data["data"]))
# Out:
# 18

# %%
match = data["data"][0]

print(match)
# Out:
# {'id': 'ca1a54c7-6c4d-4a33-a11d-5d025494ce8e', 'name': 'Papua New Guinea Women vs Thailand Women, 3rd ODI, Thailand Women tour of Papua New Guinea, 2026', 'status': 'Thailand Women won by 5 wkts', 'venue': 'Amini Park, Port Moresby', 'date': '2026-08-17', 'dateTimeGMT': '2026-08-17T23:30:00', 'teams': ['Papua New Guinea Women', 'Thailand Women'], 'teamInfo': [{'name': 'Papua New Guinea Women', 'shortname': 'PN -W', 'img': 'https://g.cricapi.com/iapi/2425-637991983542500362.webp?w=48'}, {'name': 'Thailand Women', 'shortname': 'THW', 'img': 'https://g.cricapi.com/iapi/2351-637985730472466346.webp?w=48'}], 'score': [{'r': 122, 'w': 10, 'o': 47, 'inning': 'papua new guinea women Inning 1'}, {'r': 126, 'w': 5, 'o': 27, 'inning': 'Papua New Guinea Women,Thailand Women Inning 1'}], 'series_id': '639d4a51-6405-402a-9281-17e7922e5a25', 'fantasyEnabled': False, 'bbbEnabled': False, 'hasSquad': False, 'matchStarted': True, 'matchEnded': True}

# %%
data["data"][0]
# Out:
# {'id': 'ca1a54c7-6c4d-4a33-a11d-5d025494ce8e',
#  'name': 'Papua New Guinea Women vs Thailand Women, 3rd ODI, Thailand Women tour of Papua New Guinea, 2026',
#  'status': 'Thailand Women won by 5 wkts',
#  'venue': 'Amini Park, Port Moresby',
#  'date': '2026-08-17',
#  'dateTimeGMT': '2026-08-17T23:30:00',
#  'teams': ['Papua New Guinea Women', 'Thailand Women'],
#  'teamInfo': [{'name': 'Papua New Guinea Women',
#    'shortname': 'PN -W',
#    'img': 'https://g.cricapi.com/iapi/2425-637991983542500362.webp?w=48'},
#   {'name': 'Thailand Women',
#    'shortname': 'THW',
#    'img': 'https://g.cricapi.com/iapi/2351-637985730472466346.webp?w=48'}],
#  'score': [{'r': 122,
#    'w': 10,
#    'o': 47,
#    'inning': 'papua new guinea women Inning 1'},
#   {'r': 126,
#    'w': 5,
#    'o': 27,
#    'inning': 'Papua New Guinea Women,Thailand Women Inning 1'}],
#  'series_id': '639d4a51-6405-402a-9281-17e7922e5a25',
#  'fantasyEnabled': False,
#  'bbbEnabled': False,
#  'hasSquad': False,
#  'matchStarted': True,
#  'matchEnded': True}

# %%
print("Team 1:", match["teams"][0])
print("Team 2:", match["teams"][1])

print("\nScores:")

for score in match["score"]:
    print(
        score["inning"],
        "→",
        score["r"], "runs/",
        score["w"], "wickets in",
        score["o"], "overs"
    )

print("\nResult:", match["status"])
# Out:
# Team 1: Papua New Guinea Women
# Team 2: Thailand Women
#
# Scores:
# papua new guinea women Inning 1 → 122 runs/ 10 wickets in 47 overs
# Papua New Guinea Women,Thailand Women Inning 1 → 126 runs/ 5 wickets in 27 overs
#
# Result: Thailand Women won by 5 wkts

# %%
live_matches = []

for match in data["data"]:
    if match["matchStarted"] and not match["matchEnded"]:
        live_matches.append(match)

print("Live matches:", len(live_matches))
# Out:
# Live matches: 2

# %%
for match in live_matches:
    print(match["name"])
# Out:
# Tanzania Women vs Uganda Women, 12th Match, Womens T20I Quadrangular Series in Namibia 2026
# Chepauk Super Gillies vs Vida Kovai Kings, 21st Match, Tamil Nadu Premier League 2026

# %%
live_match = live_matches[0]

print("🏏 MATCH:", live_match["name"])
print("📍 VENUE:", live_match["venue"])
print("📅 DATE:", live_match["date"])
print("📌 STATUS:", live_match["status"])
print("🏁 STARTED:", live_match["matchStarted"])
print("🏆 ENDED:", live_match["matchEnded"])
# Out:
# 🏏 MATCH: Tanzania Women vs Uganda Women, 12th Match, Womens T20I Quadrangular Series in Namibia 2026
# 📍 VENUE: Namibia Cricket Ground, Windhoek
# 📅 DATE: 2026-07-28
# 📌 STATUS: Tanzania Women awarded the match (opposition refused to play)
# 🏁 STARTED: True
# 🏆 ENDED: False

# %%
print("Team 1:", live_match["teams"][0])
print("Team 2:", live_match["teams"][1])
# Out:
# Team 1: Tanzania Women
# Team 2: Uganda Women

# %%
print("SCORES:")

for score in live_match["score"]:
    print(
        score["inning"],
        "→",
        score["r"], "runs/",
        score["w"], "wickets in",
        score["o"], "overs"
    )
# Out:
# SCORES:
# Uganda Women Inning 1 → 116 runs/ 2 wickets in 16.4 overs

# %%
print(len(live_match["score"]))
# Out:
# 1

# %%
innings = live_match["score"][0]

print("Innings:", innings["inning"])
print("Runs:", innings["r"])
print("Wickets:", innings["w"])
print("Overs:", innings["o"])
# Out:
# Innings: Uganda Women Inning 1
# Runs: 116
# Wickets: 2
# Overs: 16.4

# %%
if len(live_match["score"]) == 1:
    print("🏏 First innings is currently in progress.")
else:
    print("🏏 Second innings is currently in progress.")
# Out:
# 🏏 First innings is currently in progress.

# %%
team = innings["inning"].replace(" Inning 1", "")

runs = innings["r"]
wickets = innings["w"]
overs = innings["o"]

print("🏏 SPORTS IQ — LIVE MATCH")
print("==========================")
print("Team:", team)
print("Score:", f"{runs}/{wickets}")
print("Overs:", overs)
print("Status: 🔴 LIVE")
# Out:
# 🏏 SPORTS IQ — LIVE MATCH
# ==========================
# Team: Uganda Women
# Score: 116/2
# Overs: 16.4
# Status: 🔴 LIVE

# %%
def calculate_required_run_rate(target, current_runs, balls_remaining):
    runs_needed = target - current_runs
    
    if balls_remaining <= 0:
        return 0
    
    required_run_rate = (runs_needed / balls_remaining) * 6
    
    return required_run_rate

# %%
target = 181
current_runs = 145
balls_remaining = 22

rrr = calculate_required_run_rate(
    target,
    current_runs,
    balls_remaining
)

print("Runs needed:", target - current_runs)
print("Balls remaining:", balls_remaining)
print("Required Run Rate:", round(rrr, 2))
# Out:
# Runs needed: 36
# Balls remaining: 22
# Required Run Rate: 9.82

# %%
def win_estimate(current_rr, required_rr, wickets_remaining, balls_remaining):
    
    if required_rr <= current_rr:
        probability = 75
    elif required_rr <= current_rr + 2:
        probability = 60
    elif required_rr <= current_rr + 4:
        probability = 40
    else:
        probability = 20
    
    # Adjust slightly for wickets in hand
    if wickets_remaining >= 7:
        probability += 5
    elif wickets_remaining <= 2:
        probability -= 10
    
    # Keep probability between 5 and 95
    probability = max(5, min(probability, 95))
    
    return probability

# %%
current_rr = 10.2
required_rr = 9.8
wickets_remaining = 7
balls_remaining = 22

probability = win_estimate(
    current_rr,
    required_rr,
    wickets_remaining,
    balls_remaining
)

print("Chasing Team Win Estimate:", probability, "%")
print("Other Team:", 100 - probability, "%")
# Out:
# Chasing Team Win Estimate: 80 %
# Other Team: 20 %

# %%
import requests

ollama_url = "http://localhost:11434/api/generate"

payload = {
    "model": "llama3.2",
    "prompt": "Explain cricket in one simple sentence.",
    "stream": False
}

response = requests.post(ollama_url, json=payload)

print(response.status_code)
# Out:
# 200

# %%
result = response.json()

print(result["response"])
# Out:
# Cricket is a team sport played with a bat and ball, where two teams take turns playing offense (batting) and defense (bowling and fielding), scoring runs by hitting the ball and running between two sets of three stumps.

# %%
team = innings["inning"].replace(" Inning 1", "")

runs = innings["r"]
wickets = innings["w"]
overs = innings["o"]

match_summary = f"""
You are Sports IQ, an intelligent cricket analyst.

LIVE MATCH DATA:
Batting Team: {team}
Score: {runs}/{wickets}
Overs: {overs}

Analyze this match like a live television cricket analyst.

Give:
• Current match situation
• Key observation
• What the batting team should do next
• One exciting commentary-style sentence

Keep it concise, exciting and easy to understand.
Do not invent statistics that are not provided.
"""

# %%
payload = {
    "model": "llama3.2",
    "prompt": match_summary,
    "stream": False
}

response = requests.post(
    "http://localhost:11434/api/generate",
    json=payload
)

result = response.json()

print(result["response"])
# Out:
# "Folks, we're at 16.4 overs and Uganda Women are cruising at 116/2! The batting team is in a dominant position, with the top two batswomen, [Name] and [Name], looking comfortable at the crease.
#
# Key observation: The Uganda Women bowling attack is struggling to contain the runs, with the opposition scoring at a rate of over 7 runs per over. The bowlers need to find a way to slow down the scoring rate.
#
# What the batting team should do next: The Uganda Women batswomen should look to rotate the strike, ensuring that no single batswoman is under pressure for too long. This will help them stay focused and avoid being bowled or caught.
#
# And what a shot! [Name] just smashed a glorious pull off the [Bowler's Name] over long on, taking the score to 120!"

# %%
# !pip install pyttsx3
# Out:
# Collecting pyttsx3
#   Downloading pyttsx3-2.99-py3-none-any.whl (32 kB)
# Collecting pywin32
#   Downloading pywin32-312-cp310-cp310-win_amd64.whl (6.9 MB)
#      ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#      - -------------------------------------- 0.3/6.9 MB 5.9 MB/s eta 0:00:02
#      ----- ---------------------------------- 1.0/6.9 MB 15.6 MB/s eta 0:00:01
#      --------------- ------------------------ 2.6/6.9 MB 21.1 MB/s eta 0:00:01
#      --------------- ------------------------ 2.8/6.9 MB 16.0 MB/s eta 0:00:01
#      -------------------- ------------------- 3.5/6.9 MB 15.9 MB/s eta 0:00:01
#      ---------------------- ----------------- 3.9/6.9 MB 14.6 MB/s eta 0:00:01
#      ----------------------- ---------------- 4.1/6.9 MB 13.1 MB/s eta 0:00:01
#      ------------------------- -------------- 4.3/6.9 MB 12.0 MB/s eta 0:00:01
#      ------------------------- -------------- 4.5/6.9 MB 11.0 MB/s eta 0:00:01
#      -------------------------- ------------- 4.6/6.9 MB 10.1 MB/s eta 0:00:01
#      --------------------------- ------------ 4.7/6.9 MB 9.3 MB/s eta 0:00:01
#      --------------------------- ------------ 4.8/6.9 MB 8.7 MB/s eta 0:00:01
#      ---------------------------- ----------- 4.9/6.9 MB 8.2 MB/s eta 0:00:01
#      ---------------------------- ----------- 5.0/6.9 MB 7.6 MB/s eta 0:00:01
#      ----------------------------- ---------- 5.1/6.9 MB 7.4 MB/s eta 0:00:01
#      ------------------------------ --------- 5.2/6.9 MB 7.1 MB/s eta 0:00:01
#      ------------------------------ --------- 5.3/6.9 MB 6.8 MB/s eta 0:00:01
#      ------------------------------- -------- 5.5/6.9 MB 6.6 MB/s eta 0:00:01
#      -------------------------------- ------- 5.6/6.9 MB 6.4 MB/s eta 0:00:01
#      --------------------------------- ------ 5.8/6.9 MB 6.3 MB/s eta 0:00:01
#      ---------------------------------- ----- 5.9/6.9 MB 6.1 MB/s eta 0:00:01
#      ---------------------------------- ----- 6.0/6.9 MB 5.9 MB/s eta 0:00:01
#      ----------------------------------- ---- 6.1/6.9 MB 5.8 MB/s eta 0:00:01
#      ------------------------------------ --- 6.3/6.9 MB 5.7 MB/s eta 0:00:01
#      ------------------------------------- -- 6.5/6.9 MB 5.6 MB/s eta 0:00:01
#      -------------------------------------- - 6.6/6.9 MB 5.5 MB/s eta 0:00:01
#      ---------------------------------------  6.8/6.9 MB 5.4 MB/s eta 0:00:01
#      ---------------------------------------  6.9/6.9 MB 5.4 MB/s eta 0:00:01
#      ---------------------------------------- 6.9/6.9 MB 5.2 MB/s eta 0:00:00
# Collecting pypiwin32
#   Downloading pypiwin32-223-py3-none-any.whl (1.7 kB)
# Collecting comtypes
#   Downloading comtypes-1.4.16-py3-none-any.whl (296 kB)
#      ---------------------------------------- 0.0/296.2 kB ? eta -:--:--
#      -------------------------- ----------- 204.8/296.2 kB 6.3 MB/s eta 0:00:01
#      -------------------------------------- 296.2/296.2 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: pywin32, comtypes, pypiwin32, pyttsx3
# Successfully installed comtypes-1.4.16 pypiwin32-223 pyttsx3-2.99 pywin32-312
# [notice] A new release of pip is available: 23.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install pywin32
# Out:
# Requirement already satisfied: pywin32 in c:\users\kalyani\desktop\bhargavi\venv\lib\site-packages (312)
# [notice] A new release of pip is available: 23.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !python -m pywin32_postinstall -install
# Out:
# C:\Users\kalyani\desktop\BHARGAVI\venv\Scripts\python.exe: No module named pywin32_postinstall

# %%
# !pip install --upgrade pywin32
# Out:
# Requirement already satisfied: pywin32 in c:\users\kalyani\desktop\bhargavi\venv\lib\site-packages (312)
# [notice] A new release of pip is available: 23.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pywintypes
import pythoncom

print("pywintypes works!")
print("pythoncom works!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 import pywintypes
#       2 import pythoncom
#       4 print("pywintypes works!")
#
# ModuleNotFoundError: No module named 'pywintypes'

# %%
import os
import site

for folder in site.getsitepackages():
    print(folder)
# Out:
# C:\Users\kalyani\Desktop\BHARGAVI\venv
# C:\Users\kalyani\Desktop\BHARGAVI\venv\lib\site-packages

# %%
import os
import site

site_packages = site.getsitepackages()[0]

print("Looking in:", site_packages)

print("\npywin32 files:")
for item in os.listdir(site_packages):
    if "pywin" in item.lower():
        print(item)
# Out:
# Looking in: C:\Users\kalyani\Desktop\BHARGAVI\venv
#
# pywin32 files:

# %%
# !pip install edge-tts
# Out:
# Collecting edge-tts
#   Downloading edge_tts-7.2.8-py3-none-any.whl (31 kB)
# Collecting aiohttp<4.0.0,>=3.8.0
#   Downloading aiohttp-3.14.3-cp310-cp310-win_amd64.whl (480 kB)
#      ---------------------------------------- 0.0/480.5 kB ? eta -:--:--
#      -------------------------------------  471.0/480.5 kB 9.8 MB/s eta 0:00:01
#      ------------------------------------- 480.5/480.5 kB 10.0 MB/s eta 0:00:00
# Collecting tabulate<1.0.0,>=0.4.4
#   Downloading tabulate-0.10.0-py3-none-any.whl (39 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.1.0 in c:\users\kalyani\desktop\bhargavi\venv\lib\site-packages (from edge-tts) (4.16.0)
# Requirement already satisfied: certifi>=2023.11.17 in c:\users\kalyani\desktop\bhargavi\venv\lib\site-packages (from edge-tts) (2026.7.22)
# Collecting async-timeout<6.0,>=4.0
#   Downloading async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.7.1-cp310-cp310-win_amd64.whl (46 kB)
#      ---------------------------------------- 0.0/46.0 kB ? eta -:--:--
#      ---------------------------------------- 46.0/46.0 kB 2.2 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.8.0-cp310-cp310-win_amd64.whl (43 kB)
#      ---------------------------------------- 0.0/43.8 kB ? eta -:--:--
#      ---------------------------------------- 43.8/43.8 kB 2.2 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.17.0
#   Downloading yarl-1.24.5-cp310-cp310-win_amd64.whl (97 kB)
#      ---------------------------------------- 0.0/97.5 kB ? eta -:--:--
#      ---------------------------------------- 97.5/97.5 kB 5.8 MB/s eta 0:00:00
# Collecting aiosignal>=1.4.0
#   Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Collecting aiohappyeyeballs>=2.5.0
#   Downloading aiohappyeyeballs-2.7.1-py3-none-any.whl (15 kB)
# Collecting propcache>=0.2.0
#   Downloading propcache-0.5.2-cp310-cp310-win_amd64.whl (42 kB)
#      ---------------------------------------- 0.0/42.2 kB ? eta -:--:--
#      ---------------------------------------- 42.2/42.2 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in c:\users\kalyani\desktop\bhargavi\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts) (26.1.0)
# Requirement already satisfied: idna>=2.0 in c:\users\kalyani\desktop\bhargavi\venv\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp<4.0.0,>=3.8.0->edge-tts) (3.18)
# Installing collected packages: tabulate, propcache, multidict, frozenlist, async-timeout, aiohappyeyeballs, yarl, aiosignal, aiohttp, edge-tts
# Successfully installed aiohappyeyeballs-2.7.1 aiohttp-3.14.3 aiosignal-1.4.0 async-timeout-5.0.1 edge-tts-7.2.8 frozenlist-1.8.0 multidict-6.7.1 propcache-0.5.2 tabulate-0.10.0 yarl-1.24.5
# [notice] A new release of pip is available: 23.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import edge_tts

communicate = edge_tts.Communicate(
    "Welcome to Sports IQ. Your AI cricket analyst is ready.",
    "en-US-GuyNeural"
)

await communicate.save("test_voice.mp3")

# %%
from IPython.display import Audio

Audio("test_voice.mp3", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
commentary = result["response"]

print(commentary)
# Out:
# "Folks, we're at 16.4 overs and Uganda Women are cruising at 116/2! The batting team is in a dominant position, with the top two batswomen, [Name] and [Name], looking comfortable at the crease.
#
# Key observation: The Uganda Women bowling attack is struggling to contain the runs, with the opposition scoring at a rate of over 7 runs per over. The bowlers need to find a way to slow down the scoring rate.
#
# What the batting team should do next: The Uganda Women batswomen should look to rotate the strike, ensuring that no single batswoman is under pressure for too long. This will help them stay focused and avoid being bowled or caught.
#
# And what a shot! [Name] just smashed a glorious pull off the [Bowler's Name] over long on, taking the score to 120!"

# %%
import edge_tts

communicate = edge_tts.Communicate(
    commentary,
    "en-US-GuyNeural"
)

await communicate.save("ai_commentary.mp3")

# %%
from IPython.display import Audio

Audio("ai_commentary.mp3", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def get_cricket_data():
    response = requests.get(
        "https://api.cricapi.com/v1/currentMatches",
        params={"apikey": API_KEY}
    )
    
    return response.json()

# %%
data = get_cricket_data()

print("Matches received:", len(data["data"]))
# Out:
# Matches received: 18

# %%
def get_live_matches(data):
    live_matches = []

    for match in data["data"]:
        if match["matchStarted"] and not match["matchEnded"]:
            live_matches.append(match)

    return live_matches

# %%
live_matches = get_live_matches(data)

print("Live matches:", len(live_matches))

for match in live_matches:
    print(match["name"])
# Out:
# Live matches: 1
# Tanzania Women vs Uganda Women, 12th Match, Womens T20I Quadrangular Series in Namibia 2026

# %%
import time

for i in range(3):
    
    data = get_cricket_data()
    live_matches = get_live_matches(data)
    
    print("\n🔴 LIVE MATCHES")
    
    for match in live_matches:
        print(match["name"])
        
        for score in match["score"]:
            print(
                score["inning"],
                "→",
                score["r"], "/",
                score["w"],
                "in",
                score["o"],
                "overs"
            )
    
    print("\nChecking again...")
    time.sleep(10)
# Out:
# 🔴 LIVE MATCHES
# Tanzania Women vs Uganda Women, 12th Match, Womens T20I Quadrangular Series in Namibia 2026
# Uganda Women Inning 1 → 116 / 2 in 16.4 overs
#
# Checking again...
#
# 🔴 LIVE MATCHES
# Tanzania Women vs Uganda Women, 12th Match, Womens T20I Quadrangular Series in Namibia 2026
# Uganda Women Inning 1 → 116 / 2 in 16.4 overs
#
# Checking again...
#
# 🔴 LIVE MATCHES
# Tanzania Women vs Uganda Women, 12th Match, Womens T20I Quadrangular Series in Namibia 2026
# Uganda Women Inning 1 → 116 / 2 in 16.4 overs
#
# Checking again...

# %%
def detect_turning_point(old_score, new_score):
    
    old_runs = old_score["r"]
    new_runs = new_score["r"]
    
    old_wickets = old_score["w"]
    new_wickets = new_score["w"]
    
    if new_wickets > old_wickets:
        return "WICKET"
    
    elif new_runs > old_runs:
        runs_added = new_runs - old_runs
        return f"{runs_added} RUNS ADDED"
    
    else:
        return None

# %%
old_score = {
    "r": 116,
    "w": 2,
    "o": 16.4
}

new_score = {
    "r": 116,
    "w": 3,
    "o": 16.5
}

# %%
event = detect_turning_point(old_score, new_score)

print("Event:", event)
# Out:
# Event: WICKET

# %%
turning_point_prompt = f"""
You are Sports IQ, a live cricket analyst.

A turning point has just occurred:

Event: {event}

Previous score: {old_score["r"]}/{old_score["w"]}
New score: {new_score["r"]}/{new_score["w"]}

Explain why this event could be important to the match.

Give a short, exciting cricket commentary.
Do not invent player names or statistics.
"""

# %%
payload = {
    "model": "llama3.2",
    "prompt": turning_point_prompt,
    "stream": False
}

response = requests.post(
    "http://localhost:11434/api/generate",
    json=payload
)

turning_point_commentary = response.json()["response"]

print(turning_point_commentary)
# Out:
# "UNBELIEVABLE TURN OF EVENTS! This wicket is huge for the opposition team! They were cruising along at 116/2, and now they've brought in a new batsman to shake things up. The pressure is now on this new guy to perform, and the momentum has shifted dramatically in the other team's favor. This could be a game-changer, folks! The opposition team will be looking to capitalize on this momentum and take control of the match. Will this new batsman be able to steady the ship and turn the tide, or will the team's hopes be dashed? The tension is palpable!"

# %%
communicate = edge_tts.Communicate(
    turning_point_commentary,
    "en-US-GuyNeural"
)

await communicate.save("turning_point.mp3")

# %%
Audio("turning_point.mp3", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
cricket_knowledge = """
UGANDA WOMEN:
Uganda Women are a cricket team that participate in international women's cricket.
Their matches can include T20 and other limited-overs formats.

TANZANIA WOMEN:
Tanzania Women participate in international women's cricket.
They compete in women's limited-overs cricket.

CRICKET ANALYSIS:
In a chase, the required run rate is an important indicator.
A lower required run rate generally means less scoring pressure.
Wickets remaining are also important because losing wickets can increase pressure.

TURNING POINTS:
A wicket can become a turning point when it changes the momentum of a match.
A large scoring over can also change momentum.
A batting collapse, where several wickets fall quickly, can significantly change a team's position.

SPORTS IQ:
Sports IQ combines live cricket data, statistical calculations and AI-generated analysis.
It should not invent player names, scores or match events that are not present in the available data.
"""

# %%
def retrieve_knowledge(question):
    question = question.lower()
    
    relevant_info = []
    
    for paragraph in cricket_knowledge.split("\n\n"):
        if any(word in paragraph.lower() for word in question.split()):
            relevant_info.append(paragraph)
    
    return "\n\n".join(relevant_info)

# %%
question = "What is a turning point in cricket?"

context = retrieve_knowledge(question)

print(context)
# Out:
# UGANDA WOMEN:
# Uganda Women are a cricket team that participate in international women's cricket.
# Their matches can include T20 and other limited-overs formats.
#
# TANZANIA WOMEN:
# Tanzania Women participate in international women's cricket.
# They compete in women's limited-overs cricket.
#
# CRICKET ANALYSIS:
# In a chase, the required run rate is an important indicator.
# A lower required run rate generally means less scoring pressure.
# Wickets remaining are also important because losing wickets can increase pressure.
#
# TURNING POINTS:
# A wicket can become a turning point when it changes the momentum of a match.
# A large scoring over can also change momentum.
# A batting collapse, where several wickets fall quickly, can significantly change a team's position.
#
# SPORTS IQ:
# Sports IQ combines live cricket data, statistical calculations and AI-generated analysis.
# It should not invent player names, scores or match events that are not present in the available data.

# %%
question = "What is a turning point in cricket?"

# %%
context = retrieve_knowledge(question)

print("Retrieved Knowledge:")
print(context)
# Out:
# Retrieved Knowledge:
#
# UGANDA WOMEN:
# Uganda Women are a cricket team that participate in international women's cricket.
# Their matches can include T20 and other limited-overs formats.
#
# TANZANIA WOMEN:
# Tanzania Women participate in international women's cricket.
# They compete in women's limited-overs cricket.
#
# CRICKET ANALYSIS:
# In a chase, the required run rate is an important indicator.
# A lower required run rate generally means less scoring pressure.
# Wickets remaining are also important because losing wickets can increase pressure.
#
# TURNING POINTS:
# A wicket can become a turning point when it changes the momentum of a match.
# A large scoring over can also change momentum.
# A batting collapse, where several wickets fall quickly, can significantly change a team's position.
#
# SPORTS IQ:
# Sports IQ combines live cricket data, statistical calculations and AI-generated analysis.
# It should not invent player names, scores or match events that are not present in the available data.

# %%
rag_prompt = f"""
You are Sports IQ, an intelligent cricket assistant.

Use the following retrieved cricket knowledge to answer the user's question.

RETRIEVED KNOWLEDGE:
{context}

USER QUESTION:
{question}

Instructions:
- Answer using the retrieved knowledge.
- Keep the explanation simple.
- Do not invent cricket facts.
- If the knowledge does not contain the answer, say that the information is not available.
"""

payload = {
    "model": "llama3.2",
    "prompt": rag_prompt,
    "stream": False
}

response = requests.post(
    "http://localhost:11434/api/generate",
    json=payload
)

rag_result = response.json()

print(rag_result["response"])
# Out:
# A turning point in cricket is when a wicket becomes a crucial moment in a match, changing the momentum of the game. This can happen when a team loses a wicket, or when a large scoring over changes the scoreline. It can also occur when a batting collapse happens, leading to a significant shift in the team's position.

# %%
rag_answer = rag_result["response"]

print(rag_answer)
# Out:
# A turning point in cricket is when a wicket becomes a crucial moment in a match, changing the momentum of the game. This can happen when a team loses a wicket, or when a large scoring over changes the scoreline. It can also occur when a batting collapse happens, leading to a significant shift in the team's position.

# %%
communicate = edge_tts.Communicate(
    rag_answer,
    "en-US-GuyNeural"
)

await communicate.save("rag_answer.mp3")

# %%
Audio("rag_answer.mp3", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
